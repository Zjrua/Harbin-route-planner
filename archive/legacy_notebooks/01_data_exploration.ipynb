# %% [markdown]
# # 01 数据探索
#
# 探索哈尔滨 POI 数据的分布、类别、评分等基本统计信息。

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
# 加载原始数据
# df = pd.read_csv('../data/raw/pois_harbin.csv')
# df.head()

# %%
# TODO: POI 地理分布可视化
# TODO: 类别分布统计
# TODO: 评分分布分析
