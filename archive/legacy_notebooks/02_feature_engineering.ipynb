# %% [markdown]
# # 02 特征工程
#
# 构建 POI 特征向量、路网邻接矩阵、距离/时间矩阵。

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# TODO: 特征构建流程
# 1. 类别 one-hot 编码
# 2. 评分归一化
# 3. 季节性权重
# 4. Haversine 距离矩阵
# 5. 保存至 data/processed/
