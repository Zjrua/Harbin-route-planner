# %% [markdown]
# # 03 结果分析
#
# 分析模型训练结果、消融实验对比、路线可视化。

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
# TODO: 加载训练日志
# TODO: 绘制训练/验证 loss 曲线
# TODO: 消融实验结果对比
# TODO: 生成路线在地图上可视化
